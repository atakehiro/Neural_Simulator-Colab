# %% [markdown]
# # Brianによる神経シミュレーション
#
# 順番に Shift + Enter を押していくだけで、シミュレーションが可能です。
#
# 参考資料
#
# 1.公式チュートリアル　https://brian2.readthedocs.io/en/stable/resources/tutorials/index.html
#
# 2.Brianで神経活動シミュレーション https://qiita.com/takeajioka/items/11690b9adee612e48b33

# %% [markdown]
# ## Brianのインストール

# %%
# !pip install brian2
# Out:
# Collecting brian2
#   Downloading https://files.pythonhosted.org/packages/97/16/eda80475d70da06d59cee1a39192ee117f970eaf18adbf5fa2c926db1713/Brian2-2.3.0.2.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 7.6MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.6/dist-packages (from brian2) (1.18.5)
# Requirement already satisfied: cython>=0.29 in /usr/local/lib/python3.6/dist-packages (from brian2) (0.29.21)
# Collecting sympy>=1.2
#   Downloading https://files.pythonhosted.org/packages/e0/1f/8cbbf698e853019ac3dc5d60ca8f6be4ace4542b2f05f7b62949617fc98e/sympy-1.6.2-py3-none-any.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 43.9MB/s
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from brian2) (2.4.7)
# Requirement already satisfied: jinja2>=2.7 in /usr/local/lib/python3.6/dist-packages (from brian2) (2.11.2)
# Requirement already satisfied: setuptools>=24 in /usr/local/lib/python3.6/dist-packages (from brian2) (49.2.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from brian2) (0.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy>=1.2->brian2) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.7->brian2) (1.1.1)
# Building wheels for collected packages: brian2
#   Building wheel for brian2 (setup.py) ... done
#   Created wheel for brian2: filename=Brian2-2.3.0.2-cp36-cp36m-linux_x86_64.whl size=1283464 sha256=3e1022b1d10ffb2d2afb139bce795d48beb6acb048b3a94c591bb251705aeba1
#   Stored in directory: /root/.cache/pip/wheels/86/b5/f6/0c8f9eec58c01e4af55a4c79a5e0385aea01ed03e4ec36c4ac
# Successfully built brian2
# Installing collected packages: sympy, brian2
#   Found existing installation: sympy 1.1.1
#     Uninstalling sympy-1.1.1:
#       Successfully uninstalled sympy-1.1.1
# Successfully installed brian2-2.3.0.2 sympy-1.6.2

# %% [markdown]
# これで、GoogleColab上でBrianが使えるようになりました。(制限時間12時間)
#
# 次からは、デモを行います。

# %% [markdown]
# ## デモ１　神経細胞集団のラスタープロット

# %%
import brian2
brian2.start_scope()
# Out:
# /usr/local/lib/python3.6/dist-packages/setuptools/distutils_patch.py:26: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   "Distutils was imported before Setuptools. This usage is discouraged "

# %%
# 神経細胞集団の設定
# 100個の細胞にランダムに電位を入力している
N = 100
tau = 10 * brian2.ms #膜時定数
v0 = -50 * brian2.mV #静止膜電位
eqs = '''
dv/dt = (v0-v+I)/tau : volt (unless refractory)
I : volt
'''
G = brian2.NeuronGroup(N, eqs, threshold='v>-40*mV', reset='v=-60*mV', refractory=1*brian2.ms, method='exact')
G.v = -70 * brian2.mV
I_max = 40 * brian2.mV
G.I = 'I_max*rand()'

# %%
# モニタ変数を設定
spikemon = brian2.SpikeMonitor(G)

# %%
# シミュレーション実行
brian2.run(200*brian2.ms)

# %%
# プロット
brian2.plot(spikemon.t/brian2.ms, spikemon.i, '.k')
brian2.xlabel('Time (ms)')
brian2.ylabel('Neuron index');

# %% [markdown]
# ## デモ２　STDPによる可塑性のシミュレーション

# %%
import brian2
brian2.start_scope()

# %%
# 神経細胞集団の設定
# 100個の細胞にランダムに電位を入力している
N = 100
tau = 10 * brian2.ms #膜時定数
v0 = -50 * brian2.mV #静止膜電位
eqs = '''
dv/dt = (v0-v+I)/tau : volt (unless refractory)
I : volt
'''
G = brian2.NeuronGroup(N, eqs, threshold='v>-40*mV', reset='v=-60*mV', refractory=1*brian2.ms, method='exact')
G.v = -70 * brian2.mV
I_max = 40 * brian2.mV
G.I = 'I_max*rand()'

# %%
# シナプス結合を定義（STDP）
taupre = taupost = 20*brian2.ms
Apre = 0.01
Apost = -Apre*taupre/taupost*1.05
S = brian2.Synapses(G, G,
             '''
             w : 1
             dapre/dt = -apre/taupre : 1 (event-driven)
             dapost/dt = -apost/taupost : 1 (event-driven)
             ''',
             on_pre='''
             apre += Apre
             w = w+apost
             ''',
             on_post='''
             apost += Apost
             w = w+apre
             ''')
S.connect(condition='i!=j')

# %%
# 最初のシナプス結合
brian2.plot(S.w,'o')
brian2.xlabel('Synapse index')
brian2.ylabel('Weight');

# %%
# モニタ変数を設定
spikemon = brian2.SpikeMonitor(G)

# %%
# シミュレーション実行
brian2.run(1*brian2.second)

# %%
# 現在のシナプス結合
brian2.plot(S.w,'o')
brian2.xlabel('Synapse index')
brian2.ylabel('Weight');

# %%
# 初期のプロット
brian2.plot(spikemon.t/brian2.ms, spikemon.i, '.k')
brian2.xlabel('Time (ms)')
brian2.ylabel('Neuron index')
brian2.xlim([0, 200]);

# %%
# 最後のプロット
brian2.plot(spikemon.t/brian2.ms, spikemon.i, '.k')
brian2.xlabel('Time (ms)')
brian2.ylabel('Neuron index')
brian2.xlim([1000 - 200, 1000]);

# %% [markdown]
# シナプス結合が形成されるようになり、活動も少し変化したように思われる。
